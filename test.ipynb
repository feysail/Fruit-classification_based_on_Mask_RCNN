# %%
from os import listdir
from xml.etree import ElementTree
from numpy import zeros, asarray
from mrcnn.utils import Dataset
from matplotlib import pyplot
from mrcnn.visualize import display_instances
from mrcnn.utils import extract_bboxes
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
import random
import os
import skimage
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
class FruitsConfig(Config):
    NAME = "fruits_cfg"
    NUM_CLASSES = 1 + 3  # Background + 3 fruits
    STEPS_PER_EPOCH = 130 
    BATCH_SIZE=1


config = FruitsConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                16
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# ...

# %%
class PredictionConfig(Config):
	# define the name of the configuration
	NAME = "fruits_cfg"
	# number of classes (background + 3 fruits)
	NUM_CLASSES = 1 + 3
	# simplify GPU config
	GPU_COUNT = 1
	IMAGES_PER_GPU = 1

# %%
import skimage
import matplotlib.pyplot as pyplot
from matplotlib.patches import Rectangle  # Import Rectangle
from mrcnn import model as mrcnn_model


fruit_img = skimage.io.imread(r'C:\Users\ASUS VIVO\Downloads\Fruit_classification\datasets\test\33.jpg')

# Perform detection
detected = model.detect([fruit_img])[0]


pyplot.imshow(fruit_img)
ax = pyplot.gca()  # Get current axes
class_names = ['apple', 'banana', 'orange']

# Loop through detected boxes
for i, box in enumerate(detected['rois']):
    detected_class_id = detected['class_ids'][i]
    score = detected['scores'][i]  # Get the confidence score

    # Print detected class and score
    print(f"Detected class ID: {detected_class_id}, Score: {score}")

    # Check if the score is above a certain threshold (e.g., 0.5)
    if score > 0.5:
        y1, x1, y2, x2 = box
        width, height = x2 - x1, y2 - y1

        # Annotate the class name
        ax.annotate(class_names[detected_class_id - 1], (x1, y1), 
                    color='black', weight='bold', fontsize=10, 
                    ha='center', va='center')

        # Create and draw the rectangle
        rect = Rectangle((x1, y1), width, height, fill=False, color='red')
        ax.add_patch(rect)


pyplot.show()
# Out:
# Detected class ID: 2, Score: 0.9715723395347595
# Detected class ID: 3, Score: 0.9602290391921997
# Detected class ID: 1, Score: 0.9506277441978455

# %%
import skimage
import matplotlib.pyplot as pyplot
from matplotlib.patches import Rectangle  # Import Rectangle
from mrcnn import model as mrcnn_model


fruit_img = skimage.io.imread(r'C:\Users\ASUS VIVO\Downloads\Fruit_classification\datasets\test\01.jpg')


detected = model.detect([fruit_img])[0]


pyplot.imshow(fruit_img)
ax = pyplot.gca()  # Get current axes
class_names = ['apple', 'banana', 'orange']

# Loop through detected boxes
for i, box in enumerate(detected['rois']):
    detected_class_id = detected['class_ids'][i]
    score = detected['scores'][i]  # Get the confidence score

  
    print(f"Detected class ID: {detected_class_id}, Score: {score}")

    # Check if the score is above a certain threshold (e.g., 0.5)
    if score > 0.5:
        y1, x1, y2, x2 = box
        width, height = x2 - x1, y2 - y1


        ax.annotate(class_names[detected_class_id - 1], (x1, y1), 
                    color='black', weight='bold', fontsize=10, 
                    ha='center', va='center')

       
        rect = Rectangle((x1, y1), width, height, fill=False, color='red')
        ax.add_patch(rect)


pyplot.show()
# Out:
# Detected class ID: 2, Score: 0.8708522319793701
# Detected class ID: 1, Score: 0.7421572208404541
